# %% [markdown]
# # Phase Estimation
#
# Given a unitary operation U, the QPE estimates θ in U∣ψ⟩=e^2πiθ ∣ψ⟩

# %% [markdown]
# ## Setup

# %% [markdown]
# 1. |ψ0> = ∣0⟩^⊗n ∣ψ>
# ∣ψ> is one set of qubit registers. An additional set of n qubits form the counting register on which the value 2^n θ will be stored.
# 2. Superposition on the counting register
# 3. Controlled-Unitary operations CU

# %% [markdown]
# ## Example T-gate QPE
#
# T-gate: T|1> =
